# %% [markdown]
# # This is The Heading of a testslide

# %% [markdown]
# So let's see how this works with sub-slides

# %% [markdown]
# - reveal 1
# - reveal 1, line 2

# %% [markdown]
# - reveal 2

# %% [markdown]
# ## Subslide
# This is the upper most subslide

# %% [markdown]
# This is now the second one.

# %% [markdown]
# And number three

# %% [markdown]
# ## Going back to "real" slides

# %% [markdown]
# - introducing a new feature

# %% [markdown]
# - and another

# %% [markdown]
# - lower level
#     - or like this?

# %% [markdown]
#  - this should also work, right?

# %%
from IPython.display import Image
Image('https://upload.wikimedia.org/wikipedia/commons/thumb/c/c5/M101_hires_STScI-PRC2006-10a.jpg/1280px-M101_hires_STScI-PRC2006-10a.jpg')
